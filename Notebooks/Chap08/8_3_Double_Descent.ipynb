# %% [markdown]
# <a href="https://colab.research.google.com/github/carloscl03/tareasMateML/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-gx9tde97
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-gx9tde97
#   Resolved https://github.com/greydanus/mnist1d to commit 350929d12f4c9a4b7355e0c96604e41b9239bdb4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (2.31.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (1.25.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (3.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (2024.6.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post9) (1.16.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post9-py3-none-any.whl size=14497 sha256=8dee09444aa4b1761c113fa0c62813e6c36ac90a15b97aede791f1f0d2d13784
#   Stored in directory: /tmp/pip-ephem-wheel-cache-oclq_os_/wheels/41/95/55/45fcf7d38cfa97e35682da6c5017d4513729131326ce935371
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post9

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Length of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  # loop over the dataset n_epoch times
  n_epoch = 1000

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# es posible que un modelo de capacidad suficiente pueda aprender los datos de entrenamiento de manera perfecta. Sin embargo, lograr un error de entrenamiento cero también puede depender de factores como la complejidad de la tarea y el ruido en los datos. Dado un nivel de complejidad razonable del modelo, es posible alcanzar un error de entrenamiento cercano a cero.
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# El primer mínimo en la curva de doble descenso generalmente ocurre cuando la capacidad del modelo está cerca o ligeramente por encima del tamaño del conjunto de datos. En este caso, con 4000 ejemplos de entrenamiento, el primer mínimo podría aparecer alrededor de una capacidad de 4000 o ligeramente más alta.
# 3. At what capacity do you expect the maximum of the double descent curve to appear?
# Cuando la capacidad del modelo excede significativamente el tamaño del conjunto de datos. En este escenario, el modelo comienza a sobreajustarse, lo que lleva a un aumento en el error de prueba. Con 4000 ejemplos de entrenamiento, el máximo de la curva de doble descenso podría aparecer en una capacidad significativamente mayor que 4000, posiblemente alrededor de 8000 o más.

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;
errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Train the model
    errors_train, errors_test = fit_model(model, data)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.302524, train error 89.88,  test loss 2.302634, test error 90.18
# Epoch   100, train loss 2.302354, train error 89.65,  test loss 2.302914, test error 89.88
# Epoch   200, train loss 2.302354, train error 89.65,  test loss 2.302951, test error 89.88
# Epoch   300, train loss 2.302357, train error 89.65,  test loss 2.302949, test error 89.88
# Epoch   400, train loss 2.302360, train error 89.65,  test loss 2.302915, test error 89.88
# Epoch   500, train loss 2.302354, train error 89.65,  test loss 2.302970, test error 89.88
# Epoch   600, train loss 2.302356, train error 89.65,  test loss 2.302925, test error 89.88
# Epoch   700, train loss 2.302362, train error 89.65,  test loss 2.302951, test error 89.88
# Epoch   800, train loss 2.302356, train error 89.65,  test loss 2.302879, test error 89.88
# Epoch   900, train loss 2.302360, train error 89.65,  test loss 2.302971, test error 89.88
# Training model with   4 hidden variables
# Epoch     0, train loss 2.302047, train error 88.30,  test loss 2.302132, test error 88.43
# Epoch   100, train loss 1.734565, train error 62.35,  test loss 1.548110, test error 58.95
# Epoch   200, train loss 1.715486, train error 61.55,  test loss 1.516334, test error 58.40
# Epoch   300, train loss 1.712767, train error 61.17,  test loss 1.509620, test error 58.30
# Epoch   400, train loss 1.708837, train error 61.45,  test loss 1.514979, test error 59.12
# Epoch   500, train loss 1.706381, train error 60.97,  test loss 1.506492, test error 58.60
# Epoch   600, train loss 1.704456, train error 60.95,  test loss 1.510371, test error 58.10
# Epoch   700, train loss 1.703693, train error 61.12,  test loss 1.510122, test error 58.00
# Epoch   800, train loss 1.693777, train error 61.12,  test loss 1.499849, test error 57.55
# Epoch   900, train loss 1.686246, train error 60.90,  test loss 1.498496, test error 57.78
# Training model with   6 hidden variables
# Epoch     0, train loss 2.242304, train error 82.78,  test loss 2.227606, test error 82.45
# Epoch   100, train loss 1.665856, train error 58.88,  test loss 1.492752, test error 56.53
# Epoch   200, train loss 1.621305, train error 56.45,  test loss 1.441800, test error 54.60
# Epoch   300, train loss 1.615303, train error 55.62,  test loss 1.448350, test error 54.15
# Epoch   400, train loss 1.604184, train error 55.25,  test loss 1.435216, test error 54.08
# Epoch   500, train loss 1.604695, train error 55.55,  test loss 1.434914, test error 54.20
# Epoch   600, train loss 1.601314, train error 55.85,  test loss 1.434057, test error 54.53
# Epoch   700, train loss 1.602670, train error 55.58,  test loss 1.437428, test error 54.72
# Epoch   800, train loss 1.599780, train error 55.65,  test loss 1.436646, test error 54.95
# Epoch   900, train loss 1.595852, train error 55.75,  test loss 1.434841, test error 54.25
# Training model with   8 hidden variables
# Epoch     0, train loss 2.236103, train error 85.18,  test loss 2.218845, test error 85.22
# Epoch   100, train loss 1.594132, train error 57.03,  test loss 1.456278, test error 55.50
# Epoch   200, train loss 1.484712, train error 50.55,  test loss 1.316116, test error 49.15
# Epoch   300, train loss 1.456909, train error 49.30,  test loss 1.316909, test error 48.17
# Epoch   400, train loss 1.448441, train error 49.05,  test loss 1.323267, test error 49.58
# Epoch   500, train loss 1.443958, train error 48.80,  test loss 1.324994, test error 49.20
# Epoch   600, train loss 1.445138, train error 49.22,  test loss 1.341054, test error 49.50
# Epoch   700, train loss 1.440329, train error 48.78,  test loss 1.342481, test error 49.40
# Epoch   800, train loss 1.438057, train error 48.65,  test loss 1.337262, test error 49.40
# Epoch   900, train loss 1.436204, train error 48.85,  test loss 1.346784, test error 49.78
# Training model with  10 hidden variables
# Epoch     0, train loss 2.263497, train error 83.82,  test loss 2.253288, test error 82.07
# Epoch   100, train loss 1.568050, train error 54.78,  test loss 1.444681, test error 54.40
# Epoch   200, train loss 1.509846, train error 53.00,  test loss 1.429973, test error 53.53
# Epoch   300, train loss 1.488053, train error 51.20,  test loss 1.411528, test error 52.53
# Epoch   400, train loss 1.474316, train error 50.67,  test loss 1.393485, test error 51.72
# Epoch   500, train loss 1.453802, train error 49.88,  test loss 1.393437, test error 51.97
# Epoch   600, train loss 1.449650, train error 49.45,  test loss 1.402307, test error 51.95
# Epoch   700, train loss 1.445912, train error 49.72,  test loss 1.403675, test error 52.20
# Epoch   800, train loss 1.437540, train error 48.65,  test loss 1.399312, test error 52.17
# Epoch   900, train loss 1.428822, train error 48.42,  test loss 1.394474, test error 51.00
# Training model with  14 hidden variables
# Epoch     0, train loss 2.219926, train error 82.97,  test loss 2.188259, test error 81.72
# Epoch   100, train loss 1.468658, train error 50.38,  test loss 1.356211, test error 50.50
# Epoch   200, train loss 1.389173, train error 47.25,  test loss 1.339253, test error 49.50
# Epoch   300, train loss 1.355032, train error 45.20,  test loss 1.349622, test error 49.50
# Epoch   400, train loss 1.332044, train error 45.17,  test loss 1.375597, test error 50.20
# Epoch   500, train loss 1.312536, train error 44.12,  test loss 1.387911, test error 49.83
# Epoch   600, train loss 1.303378, train error 44.42,  test loss 1.410241, test error 50.15
# Epoch   700, train loss 1.297395, train error 44.45,  test loss 1.438723, test error 50.10
# Epoch   800, train loss 1.287732, train error 43.88,  test loss 1.457814, test error 50.72
# Epoch   900, train loss 1.287240, train error 43.83,  test loss 1.477991, test error 50.70
# Training model with  18 hidden variables
# Epoch     0, train loss 2.195237, train error 81.03,  test loss 2.171881, test error 80.62
# Epoch   100, train loss 1.336805, train error 44.33,  test loss 1.289197, test error 48.22
# Epoch   200, train loss 1.234003, train error 41.50,  test loss 1.306859, test error 48.38
# Epoch   300, train loss 1.189440, train error 39.45,  test loss 1.341200, test error 48.67
# Epoch   400, train loss 1.173517, train error 39.65,  test loss 1.370850, test error 48.78
# Epoch   500, train loss 1.165418, train error 39.65,  test loss 1.403585, test error 49.33
# Epoch   600, train loss 1.148083, train error 38.53,  test loss 1.442529, test error 49.55
# Epoch   700, train loss 1.144460, train error 38.78,  test loss 1.469306, test error 50.47
# Epoch   800, train loss 1.133126, train error 38.85,  test loss 1.507619, test error 50.38
# Epoch   900, train loss 1.139160, train error 39.35,  test loss 1.536051, test error 50.30
# Training model with  22 hidden variables
# Epoch     0, train loss 2.189620, train error 82.35,  test loss 2.175238, test error 82.50
# Epoch   100, train loss 1.283760, train error 41.47,  test loss 1.290829, test error 49.05
# Epoch   200, train loss 1.166530, train error 39.05,  test loss 1.371558, test error 49.83
# Epoch   300, train loss 1.105196, train error 36.60,  test loss 1.422610, test error 50.20
# Epoch   400, train loss 1.063791, train error 35.32,  test loss 1.488455, test error 50.88
# Epoch   500, train loss 1.046282, train error 35.10,  test loss 1.535650, test error 51.17
# Epoch   600, train loss 1.018996, train error 33.80,  test loss 1.588121, test error 51.97
# Epoch   700, train loss 1.010990, train error 32.88,  test loss 1.631590, test error 51.85
# Epoch   800, train loss 0.995143, train error 33.25,  test loss 1.680013, test error 52.05
# Epoch   900, train loss 0.974355, train error 32.32,  test loss 1.724249, test error 52.45
# Training model with  26 hidden variables
# Epoch     0, train loss 2.157892, train error 78.30,  test loss 2.121847, test error 78.68
# Epoch   100, train loss 1.140764, train error 37.38,  test loss 1.331109, test error 48.75
# Epoch   200, train loss 0.980376, train error 32.15,  test loss 1.495866, test error 50.42
# Epoch   300, train loss 0.923032, train error 30.32,  test loss 1.628387, test error 51.40
# Epoch   400, train loss 0.898737, train error 30.10,  test loss 1.733978, test error 51.78
# Epoch   500, train loss 0.875092, train error 28.72,  test loss 1.870855, test error 52.40
# Epoch   600, train loss 0.857625, train error 28.45,  test loss 1.963186, test error 53.53
# Epoch   700, train loss 0.831446, train error 27.82,  test loss 2.055457, test error 53.60
# Epoch   800, train loss 0.819919, train error 28.18,  test loss 2.182739, test error 55.00
# Epoch   900, train loss 0.817251, train error 27.70,  test loss 2.287626, test error 54.85
# Training model with  30 hidden variables
# Epoch     0, train loss 2.095477, train error 78.05,  test loss 2.064676, test error 78.12
# Epoch   100, train loss 1.083566, train error 35.35,  test loss 1.318553, test error 47.72
# Epoch   200, train loss 0.904431, train error 29.47,  test loss 1.470354, test error 49.08
# Epoch   300, train loss 0.831375, train error 26.80,  test loss 1.639051, test error 51.70
# Epoch   400, train loss 0.793189, train error 27.10,  test loss 1.802597, test error 50.85
# Epoch   500, train loss 0.741841, train error 24.90,  test loss 1.960673, test error 52.25
# Epoch   600, train loss 0.728417, train error 24.22,  test loss 2.054897, test error 52.10
# Epoch   700, train loss 0.730654, train error 24.85,  test loss 2.184672, test error 52.55
# Epoch   800, train loss 0.680684, train error 22.78,  test loss 2.294760, test error 53.17
# Epoch   900, train loss 0.675944, train error 23.25,  test loss 2.378308, test error 53.58
# Training model with  35 hidden variables
# Epoch     0, train loss 2.145856, train error 79.18,  test loss 2.116109, test error 79.00
# Epoch   100, train loss 1.009954, train error 32.07,  test loss 1.377352, test error 48.72
# Epoch   200, train loss 0.780345, train error 25.05,  test loss 1.693734, test error 51.30
# Epoch   300, train loss 0.686860, train error 22.80,  test loss 2.023462, test error 52.83
# Epoch   400, train loss 0.642602, train error 21.65,  test loss 2.336227, test error 54.40
# Epoch   500, train loss 0.582256, train error 19.15,  test loss 2.639725, test error 54.95
# Epoch   600, train loss 0.552851, train error 19.28,  test loss 2.852535, test error 54.62
# Epoch   700, train loss 0.531874, train error 18.80,  test loss 3.168214, test error 55.50
# Epoch   800, train loss 0.485485, train error 17.38,  test loss 3.370970, test error 55.17
# Epoch   900, train loss 0.473836, train error 16.55,  test loss 3.588341, test error 55.60
# Training model with  40 hidden variables
# Epoch     0, train loss 2.110649, train error 77.32,  test loss 2.100739, test error 78.12
# Epoch   100, train loss 0.913182, train error 29.40,  test loss 1.434503, test error 49.03
# Epoch   200, train loss 0.627718, train error 20.07,  test loss 1.916563, test error 52.90
# Epoch   300, train loss 0.484213, train error 15.38,  test loss 2.657602, test error 54.88
# Epoch   400, train loss 0.412976, train error 13.50,  test loss 3.446828, test error 55.42
# Epoch   500, train loss 0.421581, train error 15.15,  test loss 4.366247, test error 57.17
# Epoch   600, train loss 0.352320, train error 12.68,  test loss 5.154360, test error 58.25
# Epoch   700, train loss 0.255069, train error 8.68,  test loss 5.839699, test error 56.62
# Epoch   800, train loss 0.262395, train error 9.00,  test loss 6.514955, test error 56.40
# Epoch   900, train loss 0.284603, train error 10.35,  test loss 7.202692, test error 56.72
# Training model with  45 hidden variables
# Epoch     0, train loss 2.129756, train error 78.22,  test loss 2.113007, test error 78.93
# Epoch   100, train loss 0.817206, train error 25.85,  test loss 1.461987, test error 50.38
# Epoch   200, train loss 0.525267, train error 17.53,  test loss 2.126980, test error 52.00
# Epoch   300, train loss 0.349242, train error 11.85,  test loss 3.112536, test error 54.22
# Epoch   400, train loss 0.221153, train error 6.60,  test loss 4.239817, test error 54.45
# Epoch   500, train loss 0.176598, train error 5.72,  test loss 5.446444, test error 54.92
# Epoch   600, train loss 0.172369, train error 5.70,  test loss 6.423937, test error 54.58
# Epoch   700, train loss 0.056476, train error 1.18,  test loss 7.435207, test error 54.40
# Epoch   800, train loss 0.010079, train error 0.00,  test loss 8.374137, test error 55.08
# Epoch   900, train loss 0.006905, train error 0.00,  test loss 8.922153, test error 55.05
# Training model with  50 hidden variables
# Epoch     0, train loss 2.115260, train error 79.80,  test loss 2.090400, test error 80.30
# Epoch   100, train loss 0.734513, train error 23.32,  test loss 1.520443, test error 51.45
# Epoch   200, train loss 0.350936, train error 10.40,  test loss 2.478566, test error 54.05
# Epoch   300, train loss 0.156547, train error 3.65,  test loss 3.788286, test error 52.88
# Epoch   400, train loss 0.032790, train error 0.03,  test loss 5.371715, test error 53.92
# Epoch   500, train loss 0.013968, train error 0.00,  test loss 6.279045, test error 53.83
# Epoch   600, train loss 0.008810, train error 0.00,  test loss 6.905143, test error 54.03
# Epoch   700, train loss 0.006260, train error 0.00,  test loss 7.360087, test error 54.05
# Epoch   800, train loss 0.004765, train error 0.00,  test loss 7.725232, test error 54.22
# Epoch   900, train loss 0.003839, train error 0.00,  test loss 8.020008, test error 54.20
# Training model with  55 hidden variables
# Epoch     0, train loss 2.062834, train error 76.60,  test loss 2.021720, test error 77.20
# Epoch   100, train loss 0.612738, train error 18.15,  test loss 1.577482, test error 48.60
# Epoch   200, train loss 0.203482, train error 4.70,  test loss 2.910063, test error 53.65
# Epoch   300, train loss 0.038487, train error 0.00,  test loss 4.476975, test error 54.58
# Epoch   400, train loss 0.013771, train error 0.00,  test loss 5.389382, test error 54.80
# Epoch   500, train loss 0.008134, train error 0.00,  test loss 5.953733, test error 54.83
# Epoch   600, train loss 0.005577, train error 0.00,  test loss 6.365289, test error 55.03
# Epoch   700, train loss 0.004222, train error 0.00,  test loss 6.679951, test error 55.12
# Epoch   800, train loss 0.003345, train error 0.00,  test loss 6.936620, test error 55.12
# Epoch   900, train loss 0.002741, train error 0.00,  test loss 7.158232, test error 55.08
# Training model with  60 hidden variables
# Epoch     0, train loss 2.047573, train error 75.20,  test loss 1.989793, test error 75.40
# Epoch   100, train loss 0.523969, train error 15.47,  test loss 1.675432, test error 50.22
# Epoch   200, train loss 0.115655, train error 1.57,  test loss 3.220459, test error 52.30
# Epoch   300, train loss 0.019869, train error 0.00,  test loss 4.481060, test error 53.08
# Epoch   400, train loss 0.009375, train error 0.00,  test loss 5.134333, test error 53.25
# Epoch   500, train loss 0.005953, train error 0.00,  test loss 5.563916, test error 53.33
# Epoch   600, train loss 0.004253, train error 0.00,  test loss 5.885900, test error 53.67
# Epoch   700, train loss 0.003274, train error 0.00,  test loss 6.135544, test error 53.67
# Epoch   800, train loss 0.002631, train error 0.00,  test loss 6.342071, test error 53.58
# Epoch   900, train loss 0.002195, train error 0.00,  test loss 6.522848, test error 53.67
# Training model with  70 hidden variables
# Epoch     0, train loss 2.068232, train error 75.93,  test loss 2.052868, test error 76.72
# Epoch   100, train loss 0.332450, train error 7.68,  test loss 2.003741, test error 50.88
# Epoch   200, train loss 0.028757, train error 0.00,  test loss 3.699919, test error 53.35
# Epoch   300, train loss 0.010316, train error 0.00,  test loss 4.479793, test error 53.55
# Epoch   400, train loss 0.005808, train error 0.00,  test loss 4.917077, test error 53.50
# Epoch   500, train loss 0.003928, train error 0.00,  test loss 5.222949, test error 53.42
# Epoch   600, train loss 0.002915, train error 0.00,  test loss 5.456104, test error 53.50
# Epoch   700, train loss 0.002295, train error 0.00,  test loss 5.648825, test error 53.65
# Epoch   800, train loss 0.001873, train error 0.00,  test loss 5.809689, test error 53.70
# Epoch   900, train loss 0.001577, train error 0.00,  test loss 5.949212, test error 53.65
# Training model with  80 hidden variables
# Epoch     0, train loss 2.006515, train error 76.45,  test loss 1.927216, test error 74.55
# Epoch   100, train loss 0.232356, train error 3.97,  test loss 2.020886, test error 50.28
# Epoch   200, train loss 0.019364, train error 0.00,  test loss 3.312177, test error 51.17
# Epoch   300, train loss 0.007861, train error 0.00,  test loss 3.838369, test error 51.35
# Epoch   400, train loss 0.004655, train error 0.00,  test loss 4.155966, test error 51.70
# Epoch   500, train loss 0.003207, train error 0.00,  test loss 4.380510, test error 51.80
# Epoch   600, train loss 0.002418, train error 0.00,  test loss 4.554900, test error 51.85
# Epoch   700, train loss 0.001923, train error 0.00,  test loss 4.695250, test error 51.72
# Epoch   800, train loss 0.001584, train error 0.00,  test loss 4.815413, test error 51.67
# Epoch   900, train loss 0.001341, train error 0.00,  test loss 4.918198, test error 51.78
# Training model with  90 hidden variables
# Epoch     0, train loss 1.999687, train error 73.80,  test loss 1.913917, test error 73.78
# Epoch   100, train loss 0.135675, train error 1.00,  test loss 2.201987, test error 51.53
# Epoch   200, train loss 0.014334, train error 0.00,  test loss 3.230078, test error 52.62
# Epoch   300, train loss 0.006333, train error 0.00,  test loss 3.643078, test error 52.33
# Epoch   400, train loss 0.003881, train error 0.00,  test loss 3.902440, test error 52.42
# Epoch   500, train loss 0.002734, train error 0.00,  test loss 4.092809, test error 52.40
# Epoch   600, train loss 0.002081, train error 0.00,  test loss 4.239374, test error 52.45
# Epoch   700, train loss 0.001663, train error 0.00,  test loss 4.359988, test error 52.45
# Epoch   800, train loss 0.001378, train error 0.00,  test loss 4.461851, test error 52.33
# Epoch   900, train loss 0.001170, train error 0.00,  test loss 4.552153, test error 52.40
# Training model with 100 hidden variables
# Epoch     0, train loss 2.003162, train error 74.22,  test loss 1.936699, test error 74.38
# Epoch   100, train loss 0.092697, train error 0.12,  test loss 2.147542, test error 50.42
# Epoch   200, train loss 0.012112, train error 0.00,  test loss 2.948767, test error 50.55
# Epoch   300, train loss 0.005636, train error 0.00,  test loss 3.295337, test error 51.05
# Epoch   400, train loss 0.003512, train error 0.00,  test loss 3.513916, test error 50.97
# Epoch   500, train loss 0.002494, train error 0.00,  test loss 3.672446, test error 50.92
# Epoch   600, train loss 0.001911, train error 0.00,  test loss 3.797706, test error 50.95
# Epoch   700, train loss 0.001535, train error 0.00,  test loss 3.898601, test error 50.85
# Epoch   800, train loss 0.001275, train error 0.00,  test loss 3.984595, test error 50.70
# Epoch   900, train loss 0.001086, train error 0.00,  test loss 4.059832, test error 50.85
# Training model with 120 hidden variables
# Epoch     0, train loss 1.956456, train error 73.10,  test loss 1.899785, test error 73.78
# Epoch   100, train loss 0.054006, train error 0.03,  test loss 2.192893, test error 49.60
# Epoch   200, train loss 0.009717, train error 0.00,  test loss 2.806306, test error 49.95
# Epoch   300, train loss 0.004795, train error 0.00,  test loss 3.085291, test error 49.88
# Epoch   400, train loss 0.003055, train error 0.00,  test loss 3.269192, test error 50.10
# Epoch   500, train loss 0.002200, train error 0.00,  test loss 3.402128, test error 50.25
# Epoch   600, train loss 0.001699, train error 0.00,  test loss 3.508237, test error 50.28
# Epoch   700, train loss 0.001373, train error 0.00,  test loss 3.596501, test error 50.35
# Epoch   800, train loss 0.001146, train error 0.00,  test loss 3.671033, test error 50.28
# Epoch   900, train loss 0.000979, train error 0.00,  test loss 3.735976, test error 50.30
# Training model with 140 hidden variables
# Epoch     0, train loss 1.981224, train error 73.55,  test loss 1.909319, test error 75.22
# Epoch   100, train loss 0.037277, train error 0.00,  test loss 2.132752, test error 48.95
# Epoch   200, train loss 0.008185, train error 0.00,  test loss 2.608201, test error 48.80
# Epoch   300, train loss 0.004173, train error 0.00,  test loss 2.833233, test error 48.62
# Epoch   400, train loss 0.002703, train error 0.00,  test loss 2.981160, test error 48.60
# Epoch   500, train loss 0.001966, train error 0.00,  test loss 3.088761, test error 48.53
# Epoch   600, train loss 0.001527, train error 0.00,  test loss 3.174524, test error 48.55
# Epoch   700, train loss 0.001239, train error 0.00,  test loss 3.245270, test error 48.65
# Epoch   800, train loss 0.001037, train error 0.00,  test loss 3.306955, test error 48.62
# Epoch   900, train loss 0.000889, train error 0.00,  test loss 3.359661, test error 48.72
# Training model with 160 hidden variables
# Epoch     0, train loss 1.959993, train error 72.55,  test loss 1.918904, test error 74.30
# Epoch   100, train loss 0.028456, train error 0.00,  test loss 1.993671, test error 47.38
# Epoch   200, train loss 0.007154, train error 0.00,  test loss 2.380861, test error 47.88
# Epoch   300, train loss 0.003766, train error 0.00,  test loss 2.566971, test error 47.55
# Epoch   400, train loss 0.002476, train error 0.00,  test loss 2.693690, test error 47.65
# Epoch   500, train loss 0.001815, train error 0.00,  test loss 2.787930, test error 47.72
# Epoch   600, train loss 0.001417, train error 0.00,  test loss 2.863847, test error 47.75
# Epoch   700, train loss 0.001155, train error 0.00,  test loss 2.927946, test error 47.83
# Epoch   800, train loss 0.000969, train error 0.00,  test loss 2.982146, test error 47.75
# Epoch   900, train loss 0.000832, train error 0.00,  test loss 3.029332, test error 47.85
# Training model with 180 hidden variables
# Epoch     0, train loss 1.932806, train error 70.97,  test loss 1.849077, test error 72.05
# Epoch   100, train loss 0.023962, train error 0.00,  test loss 2.113797, test error 48.83
# Epoch   200, train loss 0.006513, train error 0.00,  test loss 2.473833, test error 48.85
# Epoch   300, train loss 0.003498, train error 0.00,  test loss 2.655472, test error 48.72
# Epoch   400, train loss 0.002320, train error 0.00,  test loss 2.778348, test error 48.92
# Epoch   500, train loss 0.001707, train error 0.00,  test loss 2.872317, test error 49.03
# Epoch   600, train loss 0.001337, train error 0.00,  test loss 2.946105, test error 49.10
# Epoch   700, train loss 0.001092, train error 0.00,  test loss 3.007888, test error 49.08
# Epoch   800, train loss 0.000918, train error 0.00,  test loss 3.061070, test error 49.00
# Epoch   900, train loss 0.000790, train error 0.00,  test loss 3.107227, test error 49.00
# Training model with 200 hidden variables
# Epoch     0, train loss 1.911125, train error 69.90,  test loss 1.855058, test error 72.28
# Epoch   100, train loss 0.021334, train error 0.00,  test loss 2.032223, test error 49.10
# Epoch   200, train loss 0.006104, train error 0.00,  test loss 2.336020, test error 48.38
# Epoch   300, train loss 0.003322, train error 0.00,  test loss 2.501446, test error 48.65
# Epoch   400, train loss 0.002216, train error 0.00,  test loss 2.610269, test error 48.50
# Epoch   500, train loss 0.001638, train error 0.00,  test loss 2.690861, test error 48.50
# Epoch   600, train loss 0.001287, train error 0.00,  test loss 2.756963, test error 48.55
# Epoch   700, train loss 0.001052, train error 0.00,  test loss 2.813106, test error 48.50
# Epoch   800, train loss 0.000886, train error 0.00,  test loss 2.859423, test error 48.50
# Epoch   900, train loss 0.000762, train error 0.00,  test loss 2.901745, test error 48.47
# Training model with 250 hidden variables
# Epoch     0, train loss 1.900180, train error 69.45,  test loss 1.826870, test error 71.00
# Epoch   100, train loss 0.016799, train error 0.00,  test loss 1.909681, test error 47.20
# Epoch   200, train loss 0.005315, train error 0.00,  test loss 2.170044, test error 47.33
# Epoch   300, train loss 0.002959, train error 0.00,  test loss 2.307629, test error 47.15
# Epoch   400, train loss 0.001997, train error 0.00,  test loss 2.401567, test error 47.05
# Epoch   500, train loss 0.001486, train error 0.00,  test loss 2.472164, test error 47.10
# Epoch   600, train loss 0.001173, train error 0.00,  test loss 2.529428, test error 47.05
# Epoch   700, train loss 0.000963, train error 0.00,  test loss 2.577702, test error 47.15
# Epoch   800, train loss 0.000813, train error 0.00,  test loss 2.619458, test error 47.08
# Epoch   900, train loss 0.000702, train error 0.00,  test loss 2.655566, test error 47.00
# Training model with 300 hidden variables
# Epoch     0, train loss 1.877029, train error 68.25,  test loss 1.798772, test error 69.47
# Epoch   100, train loss 0.014619, train error 0.00,  test loss 1.820303, test error 46.38
# Epoch   200, train loss 0.004862, train error 0.00,  test loss 2.037123, test error 46.17
# Epoch   300, train loss 0.002747, train error 0.00,  test loss 2.155421, test error 46.33
# Epoch   400, train loss 0.001870, train error 0.00,  test loss 2.235885, test error 46.12
# Epoch   500, train loss 0.001398, train error 0.00,  test loss 2.297143, test error 46.05
# Epoch   600, train loss 0.001107, train error 0.00,  test loss 2.347070, test error 46.15
# Epoch   700, train loss 0.000911, train error 0.00,  test loss 2.388271, test error 46.17
# Epoch   800, train loss 0.000771, train error 0.00,  test loss 2.424064, test error 46.12
# Epoch   900, train loss 0.000666, train error 0.00,  test loss 2.455585, test error 46.12
# Training model with 400 hidden variables
# Epoch     0, train loss 1.876369, train error 67.85,  test loss 1.852401, test error 72.22
# Epoch   100, train loss 0.011783, train error 0.00,  test loss 1.747803, test error 45.60
# Epoch   200, train loss 0.004207, train error 0.00,  test loss 1.917909, test error 45.17
# Epoch   300, train loss 0.002436, train error 0.00,  test loss 2.013533, test error 45.12
# Epoch   400, train loss 0.001679, train error 0.00,  test loss 2.081493, test error 45.12
# Epoch   500, train loss 0.001266, train error 0.00,  test loss 2.132827, test error 45.08
# Epoch   600, train loss 0.001008, train error 0.00,  test loss 2.174913, test error 45.08
# Epoch   700, train loss 0.000833, train error 0.00,  test loss 2.209673, test error 45.12
# Epoch   800, train loss 0.000707, train error 0.00,  test loss 2.240261, test error 45.10
# Epoch   900, train loss 0.000612, train error 0.00,  test loss 2.267291, test error 45.15

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all,'r-',label='train')
ax.plot(hidden_variables, errors_test_all,'b-',label='test')
ax.set_ylim(0,100);
ax.set_xlabel('No hidden variables'); ax.set_ylabel('Error')
ax.legend()
plt.show()
